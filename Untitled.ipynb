# %%
from arcgis.gis import GIS
import os
from pathlib import Path
from arcgis.learn import prepare_data, ChangeDetector
# Out:
# C:\Users\cauane\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\torch\cuda\__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
gis = GIS('home')

# %%
training_data = gis.content.get('d284e2083b254f6b8508f9cf41f53713')
training_data
# Out:
# <Item title:"change_detection_training_data" type:Image Collection owner:api_data_owner>

# %%
filepath = training_data.download(file_name=training_data.name)

# %%
import zipfile
with zipfile.ZipFile(filepath, 'r') as zip_ref:
    zip_ref.extractall(Path(filepath).parent)

data_path = Path(os.path.join(os.path.splitext(filepath)[0]))

# %%
data = prepare_data(data_path,
                    chip_size=256,
                    dataset_type='ChangeDetection', 
                    batch_size=8
                   )
# Out:
# C:\Users\cauane\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\learn\models\_arcgis_model.py:336: UserWarning: Cuda is not available
#   warnings.warn("Cuda is not available")

# %%
data.show_batch()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-08d0dd5c9f7c> in <module>
# ----> 1 data.show_batch()
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\learn\_utils\change_detection_data.py in show_batch(self, rows, **kwargs)
#     744     img_idxs = [random.randint(0, len(self.train_ds) - 1) for k in range(rows)]
#     745     for idx, im_idx in enumerate(img_idxs):
# --> 746         self.train_ds.show(im_idx, axes[idx], rgb_bands)
#     747
#     748
#
# ~\AppData\Local\Programs\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\learn\_utils\change_detection_data.py in show(self, idx, axes, rgb_bands)
#     373         if rgb_bands is None:
#     374             rgb_bands = self.rgb_bands
# --> 375         self[idx]
#     376         if axes is None:
# ...

# %%
"""Load model architecture
arcgis.learn provides the ChangeDetector model for identifying areas of persistent change tasks,
which is based on a pretrained convnet, like ResNet that acts as the 'backbone'
"""
cd = ChangeDetector(data, backbone='resnet50')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to C:\Users\cauane/.cache\torch\hub\checkpoints\resnet50-19c8e357.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
# Train the model
lr = cd.lr_find()

# %%
# Visualize detected changes
cd.show_results(rows=5)

# %%
# Evaluate model performance
cd.precision_recall_score()
# Out:
#            NoChange  Change
# precision  0.702019     0.0
# recall     1.000000     0.0
# f1         0.824557     0.0

# %%
# Save model
cd.save('change_detection_model_e200')

# %%
# import fastai
# print(fastai.__version__)

# import torch
# print(torch.__version__)

# import torchvision
# print(torchvision.__version__)
